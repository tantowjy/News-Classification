# %%
# !pip install sastrawi
# Out:
# Collecting sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.7 MB/s eta 0:00:00
# Installing collected packages: sastrawi
# Successfully installed sastrawi-1.0.1

# %%
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, StopWordRemover, ArrayDictionary
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
df=pd.read_json("https://raw.githubusercontent.com/Zaniiiii/Data/main/pukul6/bias/berlabel/dataset_bias_tribun_label.json",lines=True)
df
# Out:
#                                                  title platform  \
# 0    Gerindra Respons Soal Kadernya Ramai-ramai Jad...   tribun
# 1    Pengamat Sebut Revisi UU MD3 Lebih Politis dan...   tribun
# 2    VIDEO WAWANCARA EKSKLUSIF Calon Pemimpin Bekas...   tribun
# 3    Ramai soal Buku Bergambar Jan Ethes: Gibran Mi...   tribun
# 4    Gibran Jawab Kritikan soal Bagi Buku Bersampul...   tribun
# ..                                                 ...      ...
# 183  Plt Kepala OIKN Rapat dengan Komisi V, Lasarus...   tribun
# 184  Komnas Perempuan: Penyelenggara Pemilu yang La...   tribun
# 185  Qodari Buka-bukaan Soal Konstelasi Politik, Bi...   tribun
# 186  Respons Istana Soal Buruh yang Akan Demo Tolak...   tribun
# 187  Mampu Mengonsolidasikan Kader Hingga Hasil Pem...   tribun
#
#                                                    url  \
# 0    https://www.tribunnews.com/nasional/2024/06/13...
# 1    https://www.tribunnews.com/nasional/2024/06/13...
# 2    https://www.tribunnews.com/nasional/2024/06/13...
# 3    https://www.tribunnews.com/nasional/2024/06/13...
# 4    https://www.tribunnews.com/nasional/2024/06/13...
# ..                                                 ...
# 183  https://www.tribunnews.com/nasional/2024/06/06...
# 184  https://www.tribunnews.com/nasional/2024/06/06...
# 185  https://www.tribunnews.com/nasional/2024/06/06...
# 186  https://www.tribunnews.com/nasional/2024/06/06...
# 187  https://www.tribunnews.com/nasional/2024/06/05...
#
#                               date  \
# 0    Kamis, 13 Juni 2024 16:23 WIB
# 1    Kamis, 13 Juni 2024 15:14 WIB
# 2    Kamis, 13 Juni 2024 14:15 WIB
# 3    Kamis, 13 Juni 2024 14:15 WIB
# 4    Kamis, 13 Juni 2024 13:06 WIB
# ..                             ...
# 183   Kamis, 6 Juni 2024 11:50 WIB
# 184   Kamis, 6 Juni 2024 11:06 WIB
# 185   Kamis, 6 Juni 2024 09:40 WIB
# 186   Kamis, 6 Juni 2024 09:40 WIB
# 187    Rabu, 5 Juni 2024 22:06 WIB
#
#                                                content  bias
# 0    Laporan Wartawan Tribunnews.com, Igman Ibrahim...     1
# 1    TRIBUNNEWS.COM, JAKARTA - Pengamat Politik Her...     1
# 2    TRIBUNNEWS.COM, JAKARTA - Wakil Sekretaris Jen...     0
# 3    TRIBUNNEWS.COM - Tindakan wakil presiden terpi...     0
# 4    TRIBUNNEWS.COM - Wali Kota Solo sekaligus Waki...     1
# ..                                                 ...   ...
# 183  Laporan Wartawan Tribunnews.com, Chaerul Umam ...     1
# 184  Laporan Wartawan Tribunnews, Mario Christian S...     1
# 185  TRIBUNNEWS.COM, JAKARTA - Pengamat politik dan...     1
# 186  TRIBUNNEWS.COM, JAKARTA - Istana melalui Mente...     1
# 187  TRIBUNNEWS.COM, JAKARTA - Mampu Mengonsolidasi...     0
#
# [188 rows x 6 columns]

# %%
df['content'] = df['content'].str.split('TRIBUNNEWS.COM').str[1]
df['content'] = df['content'].str.split(' - ').str[1]

df
# Out:
#                                                  title platform  \
# 0    Gerindra Respons Soal Kadernya Ramai-ramai Jad...   tribun
# 1    Pengamat Sebut Revisi UU MD3 Lebih Politis dan...   tribun
# 2    VIDEO WAWANCARA EKSKLUSIF Calon Pemimpin Bekas...   tribun
# 3    Ramai soal Buku Bergambar Jan Ethes: Gibran Mi...   tribun
# 4    Gibran Jawab Kritikan soal Bagi Buku Bersampul...   tribun
# ..                                                 ...      ...
# 183  Plt Kepala OIKN Rapat dengan Komisi V, Lasarus...   tribun
# 184  Komnas Perempuan: Penyelenggara Pemilu yang La...   tribun
# 185  Qodari Buka-bukaan Soal Konstelasi Politik, Bi...   tribun
# 186  Respons Istana Soal Buruh yang Akan Demo Tolak...   tribun
# 187  Mampu Mengonsolidasikan Kader Hingga Hasil Pem...   tribun
#
#                                                    url  \
# 0    https://www.tribunnews.com/nasional/2024/06/13...
# 1    https://www.tribunnews.com/nasional/2024/06/13...
# 2    https://www.tribunnews.com/nasional/2024/06/13...
# 3    https://www.tribunnews.com/nasional/2024/06/13...
# 4    https://www.tribunnews.com/nasional/2024/06/13...
# ..                                                 ...
# 183  https://www.tribunnews.com/nasional/2024/06/06...
# 184  https://www.tribunnews.com/nasional/2024/06/06...
# 185  https://www.tribunnews.com/nasional/2024/06/06...
# 186  https://www.tribunnews.com/nasional/2024/06/06...
# 187  https://www.tribunnews.com/nasional/2024/06/05...
#
#                               date  \
# 0    Kamis, 13 Juni 2024 16:23 WIB
# 1    Kamis, 13 Juni 2024 15:14 WIB
# 2    Kamis, 13 Juni 2024 14:15 WIB
# 3    Kamis, 13 Juni 2024 14:15 WIB
# 4    Kamis, 13 Juni 2024 13:06 WIB
# ..                             ...
# 183   Kamis, 6 Juni 2024 11:50 WIB
# 184   Kamis, 6 Juni 2024 11:06 WIB
# 185   Kamis, 6 Juni 2024 09:40 WIB
# 186   Kamis, 6 Juni 2024 09:40 WIB
# 187    Rabu, 5 Juni 2024 22:06 WIB
#
#                                                content  bias
# 0    Sejumlah kader partai Gerindra ramai-ramai men...     1
# 1    Pengamat Politik Herry Mendrofa ikut menyoroti...     1
# 2    Wakil Sekretaris Jenderal Partai Golkar, Nofel...     0
# 3    Tindakan wakil presiden terpilih Gibran Rakabu...     0
# 4    Wali Kota Solo sekaligus Wakil Presiden Terpil...     1
# ..                                                 ...   ...
# 183  Komisi V DPR RI menggelar rapat kerja (raker) ...     1
# 184  Komisi Nasional Anti Kekerasan terhadap Peremp...     1
# 185  Pengamat politik dan Direktur Eksekutif Indo B...     1
# 186  Istana melalui Menteri Sekretaris Negara Prati...     1
# 187  Mampu Mengonsolidasikan Kader Hingga Hasil Pem...     0
#
# [188 rows x 6 columns]

# %%
# #Hapus  ADVERTISEMENT SCROLL TO CONTINUE WITH CONTENT, :[Gambas:Video 20detik]
# def clean_content(content):
#     # Remove \r, \n, and any other unwanted characters
#     content = re.sub(r'[\r\n]', ' ', content)

#     # Remove multiple spaces
#     content = re.sub(r'\s+', ' ', content).strip()
#     content = content.replace("[Gambas:Video 20detik]", "")
#     content = content.replace("ADVERTISEMENT SCROLL TO CONTINUE WITH CONTENT", "")
#     content = content.replace("ADVERTISEMENT", "")
#     return content.strip()

# # Apply the cleaning function to the dataframe
# df["content"] = df["content"].apply(clean_content)
# df
# Out:
#                                                 title platform  \
# 0   Dua Politisi Golkar Jaro Ade dan Sulhajji Jomp...    suara
# 1   Waspada Politik Uang di Pilkada PPU! Peserta B...    suara
# 2   Rekam Jejak Tsamara Amany, Eks Kader PSI yang ...    suara
# 3   Mahasiswa Klaim Punya Bukti Kuat Politik Uang,...    suara
# 4   Hasto Dipanggil KPK Soal Harun Masiku, Pukat U...    suara
# ..                                                ...      ...
# 83  Survei Persepsi Masyarakat Kota Yogyakarta Res...    suara
# 84  Pengamat Politik Sebut Cilegon Butuh 'Sosok Ba...    suara
# 85  Pilkada Bontang 2024: Drama Politik Pasangan P...    suara
# 86  Pakar Politik Sebut PAN Masih Berhitung Soal P...    suara
# 87  Anggota Tim Ahli Wantimpres Prof Henry Indragu...    suara
#
#                                                  link  \
# 0   https://www.suara.com/news/2024/06/12/191016/d...
# 1   https://kaltim.suara.com/read/2024/06/12/18300...
# 2   https://www.suara.com/lifestyle/2024/06/12/122...
# 3   https://sulsel.suara.com/read/2024/06/11/18130...
# 4   https://www.suara.com/news/2024/06/10/162255/h...
# ..                                                ...
# 83  https://jogja.suara.com/read/2024/05/14/163522...
# 84  https://www.suara.com/news/2024/05/14/091729/p...
# 85  https://kaltim.suara.com/read/2024/05/12/17450...
# 86  https://www.suara.com/news/2024/05/10/235549/p...
# 87  https://www.suara.com/pressrelease/2024/05/10/...
#
#                                 date  \
# 0     Rabu, 12 Juni 2024 | 19:10 WIB
# 1     Rabu, 12 Juni 2024 | 18:30 WIB
# 2     Rabu, 12 Juni 2024 | 12:25 WIB
# 3   Selasa, 11 Juni 2024 | 18:13 WIB
# 4    Senin, 10 Juni 2024 | 16:22 WIB
# ..                               ...
# 83   Selasa, 14 Mei 2024 | 16:35 WIB
# 84   Selasa, 14 Mei 2024 | 09:17 WIB
# 85   Minggu, 12 Mei 2024 | 17:45 WIB
# 86   Jum'at, 10 Mei 2024 | 23:55 WIB
# 87   Jum'at, 10 Mei 2024 | 08:05 WIB
#
#                                               content  bias
# 0   Sekretaris PKB Kabupaten Bogor, Nurodin alias ...     1
# 1   Badan Pengawas Pemilu (Bawaslu) Kabupaten Pena...     1
# 2   Sosok Tsamara Amany kembali disorot setelah be...     0
# 3   Badan Pengawas Pemilu (Bawaslu) Kota Makassar ...     0
# 4   Komisi Pemberantasan Korupsi (KPK) memanggil S...     1
# ..                                                ...   ...
# 83  Muda Bicara ID kembali menggelar survei tentan...     1
# 84  Menjalang pelaksanaan pemilihan Kepala Daerah ...     0
# 85  Keputusan Basri Rase menempuh jalur non-partai...     1
# 86  Mantan Wali Kota Bogor, Bima Arya disebut berp...     1
# 87  Politisi Partai Golkar asal Jateng Prof Dr Hen...     1
#
# [88 rows x 6 columns]

# %%
import nltk
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.corpus import stopwords
import re
from tqdm import tqdm
from multiprocessing import Pool
from functools import lru_cache

nltk.download('stopwords')
stop_words = set(stopwords.words('indonesian'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def clean_text(text):
    if isinstance(text, str):
        # Remove non-alphanumeric characters
        text = re.sub(r'\W', ' ', text)
        # Remove single characters
        text = re.sub(r'\s+[a-zA-Z]\s+', ' ', text)
        # Remove single characters from the start
        text = re.sub(r'\^[a-zA-Z]\s+', ' ', text)
        # Remove numbers
        text = re.sub(r'\d+', '', text)
        # Substituting multiple spaces with single space
        text = re.sub(r'\s+', ' ', text, flags=re.I)
        # Remove prefixed 'b'
        text = re.sub(r'^b\s+', '', text)
        # Convert to lowercase
        text = text.lower()
        # Remove stopwords
        text = ' '.join([word for word in text.split() if word not in stop_words])
        text = stemmer.stem(text)
    else:
        text = ''
    return text

# %%
import pandas as pd
import time
from multiprocessing import Pool

# Fungsi untuk membersihkan teks dengan progress bar
def clean_text_with_progress(x,y):
    start_time = time.time()

    # Menggunakan multiprocessing Pool untuk membersihkan teks secara paralel
    with Pool() as pool:
        cleaned_content = list(tqdm(pool.imap(clean_text, x), total=len(df), desc="Cleaning texts", unit="text"))

    end_time = time.time()
    total_time = end_time - start_time
    avg_time_per_row = total_time / len(df)

    df[y] = cleaned_content
    print("Estimasi waktu pembersihan per baris: {:.6f} detik".format(avg_time_per_row))
    print("Total waktu pembersihan: {:.6f} detik".format(total_time))

clean_text_with_progress(df["content"],"content")
clean_text_with_progress(df["title"],"title")
# Out:
# Cleaning texts: 100%|██████████| 188/188 [04:38<00:00,  1.48s/text]
# Estimasi waktu pembersihan per baris: 1.479622 detik
# Total waktu pembersihan: 278.169001 detik
# Cleaning texts: 100%|██████████| 188/188 [00:38<00:00,  4.89text/s]
# Estimasi waktu pembersihan per baris: 0.204670 detik
# Total waktu pembersihan: 38.477983 detik

# %%
df
# Out:
#                                                  title platform  \
# 0    gerindra respons kader ramai ramai komisaris b...   tribun
# 1              amat revisi uu md politis milik urgensi   tribun
# 2    video wawancara eksklusif calon pimpin bekas w...   tribun
# 3    ramai buku gambar jan ethes gibran maaf kisah ...   tribun
# 4    gibran kritik buku sampul jan ethes surabaya m...   tribun
# ..                                                 ...      ...
# 183  plt kepala oikn rapat komisi lasarus selamat t...   tribun
# 184  komnas perempuan selenggara milu laku tindak k...   tribun
# 185  qodari buka buka konstelasi politik bicara ala...   tribun
# 186             respons istana buruh demo tolak tapera   tribun
# 187  konsolidasi kader hasil milu nilai modal airla...   tribun
#
#                                                    url  \
# 0    https://www.tribunnews.com/nasional/2024/06/13...
# 1    https://www.tribunnews.com/nasional/2024/06/13...
# 2    https://www.tribunnews.com/nasional/2024/06/13...
# 0    kader partai gerindra ramai ramai komisaris bu...     1
# 1    amat politik herry mendrofa sorot rencana revi...     1
# 2    wakil sekretaris jenderal partai golkar nofel ...     0
# 3    tindak wakil presiden pilih gibran rakabuming ...     0
# 4    wali kota solo wakil presiden pilih gibran rak...     1
# ..                                                 ...   ...
# 183  komisi dpr ri gelar rapat kerja raker menteri ...     1
# 184  komisi nasional anti keras perempuan komnas pe...     1
# 185  amat politik direktur eksekutif indo barometer...     1
# 186  istana menteri sekretaris negara pratikno aku ...     1
# 187  konsolidasi kader hasil milu nilai modal airla...     0
#
# [188 rows x 6 columns]

# %%
df1['gabung'] = df1['platform'] + ' ' + df1['title'] + ' ' + df1['content']
df1
# Out:
#                                                  title platform  \
# 0    gerindra respons kader ramai ramai komisaris b...   tribun
# 1              amat revisi uu md politis milik urgensi   tribun
# 2    video wawancara eksklusif calon pimpin bekas w...   tribun
# 3    ramai buku gambar jan ethes gibran maaf kisah ...   tribun
# 4    gibran kritik buku sampul jan ethes surabaya m...   tribun
# ..                                                 ...      ...
# 183  plt kepala oikn rapat komisi lasarus selamat t...   tribun
# 184  komnas perempuan selenggara milu laku tindak k...   tribun
# 185  qodari buka buka konstelasi politik bicara ala...   tribun
# 186             respons istana buruh demo tolak tapera   tribun
# 187  konsolidasi kader hasil milu nilai modal airla...   tribun
#
#                                                    url  \
# 0    https://www.tribunnews.com/nasional/2024/06/13...
# 1    https://www.tribunnews.com/nasional/2024/06/13...
# 2    https://www.tribunnews.com/nasional/2024/06/13...
# 3    https://www.tribunnews.com/nasional/2024/06/13...
# 4    https://www.tribunnews.com/nasional/2024/06/13...
# ..                                                 ...
# 183  https://www.tribunnews.com/nasional/2024/06/06...
# 184  https://www.tribunnews.com/nasional/2024/06/06...
# 185  https://www.tribunnews.com/nasional/2024/06/06...
# 186  https://www.tribunnews.com/nasional/2024/06/06...
# 187  https://www.tribunnews.com/nasional/2024/06/05...
#
#                               date  \
# 0    Kamis, 13 Juni 2024 16:23 WIB
# 1    Kamis, 13 Juni 2024 15:14 WIB
# 2    Kamis, 13 Juni 2024 14:15 WIB
# 3    Kamis, 13 Juni 2024 14:15 WIB
# 4    Kamis, 13 Juni 2024 13:06 WIB
# ..                             ...
# 183   Kamis, 6 Juni 2024 11:50 WIB
# 184   Kamis, 6 Juni 2024 11:06 WIB
# 185   Kamis, 6 Juni 2024 09:40 WIB
# 186   Kamis, 6 Juni 2024 09:40 WIB
# 187    Rabu, 5 Juni 2024 22:06 WIB
#
#                                                content  bias  \
# 0    kader partai gerindra ramai ramai komisaris bu...     1
# 1    amat politik herry mendrofa sorot rencana revi...     1
# 2    wakil sekretaris jenderal partai golkar nofel ...     0
# 3    tindak wakil presiden pilih gibran rakabuming ...     0
# 4    wali kota solo wakil presiden pilih gibran rak...     1
# ..                                                 ...   ...
# 183  komisi dpr ri gelar rapat kerja raker menteri ...     1
# 184  komisi nasional anti keras perempuan komnas pe...     1
# 185  amat politik direktur eksekutif indo barometer...     1
# 186  istana menteri sekretaris negara pratikno aku ...     1
# 187  konsolidasi kader hasil milu nilai modal airla...     0
#
#                                                 gabung
# 0    tribun gerindra respons kader ramai ramai komi...
# 1    tribun amat revisi uu md politis milik urgensi...
# 2    tribun video wawancara eksklusif calon pimpin ...
# 3    tribun ramai buku gambar jan ethes gibran maaf...
# 4    tribun gibran kritik buku sampul jan ethes sur...
# ..                                                 ...
# 183  tribun plt kepala oikn rapat komisi lasarus se...
# 184  tribun komnas perempuan selenggara milu laku t...
# 185  tribun qodari buka buka konstelasi politik bic...
# 186  tribun respons istana buruh demo tolak tapera ...
# 187  tribun konsolidasi kader hasil milu nilai moda...
#
# [188 rows x 7 columns]

# %%
df1 = df1[["gabung",'bias']]
# df1.rename(columns={'gabung': 'title'}, inplace=True)
df1
# Out:
#                                                 gabung  bias
# 0    tribun gerindra respons kader ramai ramai komi...     1
# 1    tribun amat revisi uu md politis milik urgensi...     1
# 2    tribun video wawancara eksklusif calon pimpin ...     0
# 3    tribun ramai buku gambar jan ethes gibran maaf...     0
# 4    tribun gibran kritik buku sampul jan ethes sur...     1
# ..                                                 ...   ...
# 183  tribun plt kepala oikn rapat komisi lasarus se...     1
# 184  tribun komnas perempuan selenggara milu laku t...     1
# 185  tribun qodari buka buka konstelasi politik bic...     1
# 186  tribun respons istana buruh demo tolak tapera ...     1
# 187  tribun konsolidasi kader hasil milu nilai moda...     0
#
# [188 rows x 2 columns]

# %%
df["gabung"] = df['platform'] + ' ' + df['title']
df
# Out:
#                                                  title platform  \
# 0    gerindra respons kader ramai ramai komisaris b...   tribun
# 1              amat revisi uu md politis milik urgensi   tribun
# 2    video wawancara eksklusif calon pimpin bekas w...   tribun
# 3    ramai buku gambar jan ethes gibran maaf kisah ...   tribun
# 4    gibran kritik buku sampul jan ethes surabaya m...   tribun
# ..                                                 ...      ...
# 183  plt kepala oikn rapat komisi lasarus selamat t...   tribun
# 184  komnas perempuan selenggara milu laku tindak k...   tribun
# 185  qodari buka buka konstelasi politik bicara ala...   tribun
# 186             respons istana buruh demo tolak tapera   tribun
# 187  konsolidasi kader hasil milu nilai modal airla...   tribun
#
#                                                    url  \
# 0    https://www.tribunnews.com/nasional/2024/06/13...
# 1    https://www.tribunnews.com/nasional/2024/06/13...
# 2    https://www.tribunnews.com/nasional/2024/06/13...
# 3    https://www.tribunnews.com/nasional/2024/06/13...
# 4    https://www.tribunnews.com/nasional/2024/06/13...
# ..                                                 ...
# 183  https://www.tribunnews.com/nasional/2024/06/06...
# 184  https://www.tribunnews.com/nasional/2024/06/06...
# 185  https://www.tribunnews.com/nasional/2024/06/06...
# 186  https://www.tribunnews.com/nasional/2024/06/06...
# 187  https://www.tribunnews.com/nasional/2024/06/05...
#
#                               date  \
# 0    Kamis, 13 Juni 2024 16:23 WIB
# 1    Kamis, 13 Juni 2024 15:14 WIB
# 2    Kamis, 13 Juni 2024 14:15 WIB
# 3    Kamis, 13 Juni 2024 14:15 WIB
# 4    Kamis, 13 Juni 2024 13:06 WIB
# ..                             ...
# 183   Kamis, 6 Juni 2024 11:50 WIB
# 184   Kamis, 6 Juni 2024 11:06 WIB
# 185   Kamis, 6 Juni 2024 09:40 WIB
# 186   Kamis, 6 Juni 2024 09:40 WIB
# 187    Rabu, 5 Juni 2024 22:06 WIB
#
#                                                content  bias  \
# 0    kader partai gerindra ramai ramai komisaris bu...     1
# 1    amat politik herry mendrofa sorot rencana revi...     1
# 2    wakil sekretaris jenderal partai golkar nofel ...     0
# 3    tindak wakil presiden pilih gibran rakabuming ...     0
# 4    wali kota solo wakil presiden pilih gibran rak...     1
# ..                                                 ...   ...
# 183  komisi dpr ri gelar rapat kerja raker menteri ...     1
# 184  komisi nasional anti keras perempuan komnas pe...     1
# 185  amat politik direktur eksekutif indo barometer...     1
# 186  istana menteri sekretaris negara pratikno aku ...     1
# 187  konsolidasi kader hasil milu nilai modal airla...     0
#
#                                                 gabung
# 0    tribun gerindra respons kader ramai ramai komi...
# 1       tribun amat revisi uu md politis milik urgensi
# 2    tribun video wawancara eksklusif calon pimpin ...
# 3    tribun ramai buku gambar jan ethes gibran maaf...
# 4    tribun gibran kritik buku sampul jan ethes sur...
# ..                                                 ...
# 183  tribun plt kepala oikn rapat komisi lasarus se...
# 184  tribun komnas perempuan selenggara milu laku t...
# 185  tribun qodari buka buka konstelasi politik bic...
# 186      tribun respons istana buruh demo tolak tapera
# 187  tribun konsolidasi kader hasil milu nilai moda...
#
# [188 rows x 7 columns]

# %%
df = df[["gabung",'bias']]

# %%
df
# Out:
#                                                 gabung  bias
# 0    tribun gerindra respons kader ramai ramai komi...     1
# 1       tribun amat revisi uu md politis milik urgensi     1
# 2    tribun video wawancara eksklusif calon pimpin ...     0
# 3    tribun ramai buku gambar jan ethes gibran maaf...     0
# 4    tribun gibran kritik buku sampul jan ethes sur...     1
# ..                                                 ...   ...
# 183  tribun plt kepala oikn rapat komisi lasarus se...     1
# 184  tribun komnas perempuan selenggara milu laku t...     1
# 185  tribun qodari buka buka konstelasi politik bic...     1
# 186      tribun respons istana buruh demo tolak tapera     1
# 187  tribun konsolidasi kader hasil milu nilai moda...     0
#
# [188 rows x 2 columns]

# %%
df = pd.concat([df,df1], axis=0, ignore_index=True)
df
# Out:
#                                                 gabung  bias
# 0    tribun gerindra respons kader ramai ramai komi...     1
# 1       tribun amat revisi uu md politis milik urgensi     1
# 2    tribun video wawancara eksklusif calon pimpin ...     0
# 3    tribun ramai buku gambar jan ethes gibran maaf...     0
# 4    tribun gibran kritik buku sampul jan ethes sur...     1
# ..                                                 ...   ...
# 371  tribun plt kepala oikn rapat komisi lasarus se...     1
# 372  tribun komnas perempuan selenggara milu laku t...     1
# 373  tribun qodari buka buka konstelasi politik bic...     1
# 374  tribun respons istana buruh demo tolak tapera ...     1
# 375  tribun konsolidasi kader hasil milu nilai moda...     0
#
# [376 rows x 2 columns]

# %%
df.to_json('dataset_bias_tribun_clean.json', orient='records', lines=True)
